# %%
# !nvidia-smi

# %%
# !pip install ultralytics roboflow

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="V2C7VaG04x3h3dscUQo9")
project = rf.workspace("sarvarbeks-workspace").project("car-parts-segmentation-2atbn")
dataset = project.version(1).download("yolov8")

# %%
from ultralytics import YOLO

model = YOLO("yolov8n-seg.pt")

model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    project="auto-damage-segmentation",
    name="car-parts",
    save=True
)

# %%
from ultralytics import YOLO

model = YOLO("yolov8n-seg.pt")

model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    project="auto-damage-segmentation",
    name="car-parts",
    save=True
)

# %%
import glob

weights = glob.glob("auto-damage-segmentation/car-parts*/weights/best.pt")
print(weights[0])

# %%
model = YOLO(weights[0])
model.export(format="onnx")
print("ONNX export tayyor!")
